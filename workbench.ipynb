# %%
from ipynb.fs.full.datagetter import *
from ipynb.fs.full.forest import predict, backtest

# %%
stop_time = datetime.datetime.now() + datetime.timedelta(minutes=3)

# %%
test_data = get_data('AAPL', stop_time, 5)

# %%
test_data
# Out:
#   Symbol   Price Change Percent      Time
# 0   AAPL  177.79  +0.06   +0.03  18:42:03
# 0   AAPL  177.79  +0.06   +0.03  18:42:05
# 0   AAPL  177.79  +0.06   +0.03  18:42:11
# 0   AAPL  177.79  +0.06   +0.03  18:42:18
# 0   AAPL  177.79  +0.06   +0.03  18:42:24
# 0   AAPL  177.79  +0.06   +0.03  18:42:31
# 0   AAPL  177.79  +0.06   +0.03  18:42:37
# 0   AAPL  177.79  +0.06   +0.03  18:42:44
# 0   AAPL  177.79  +0.06   +0.03  18:42:50
# 0   AAPL  177.79  +0.06   +0.03  18:42:57
# 0   AAPL  177.79  +0.06   +0.03  18:43:03
# 0   AAPL  177.79  +0.06   +0.03  18:43:09
# 0   AAPL  177.79  +0.06   +0.03  18:43:16
# 0   AAPL  177.79  +0.06   +0.03  18:43:22
# 0   AAPL  177.79  +0.06   +0.03  18:43:29
# 0   AAPL  177.79  +0.06   +0.03  18:43:35
# 0   AAPL  177.79  +0.06   +0.03  18:43:41
# 0   AAPL  177.79  +0.06   +0.03  18:43:48
# 0   AAPL  177.79  +0.06   +0.03  18:43:54
# 0   AAPL  177.79  +0.06   +0.03  18:44:01
# 0   AAPL  177.79  +0.06   +0.03  18:44:07
# ...

# %%
# manually make a prediction
